# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
import gmaps

# Census API Keys
from config import api_key
c = Census(api_key, year=2018)

# %% [markdown]
# ### Senior Male Census Data

# %%
census_data_male = c.acs1.get(("NAME", "B01003_001E", "B01001_020E", "B01001_021E", "B01001_022E",
                          "B01001_023E",
                          "B01001_024E",
                          "B01001_025E"), {'for': 'state:*'})

# %%
census_pd_male = pd.DataFrame(census_data_male)

# %%
census_pd_male = census_pd_male.rename(columns={"B01003_001E": "Population",
                                                "NAME": "Name", "state": "State"})

# %%
col = list(census_pd_male)

# %%
col = col[2:-1]

# %%
census_pd_male['Seniors'] = census_pd_male[col].sum(axis=1)

# %% [markdown]
# ### Senior Female Census Data

# %%
census_data_f = c.acs1.get(("NAME", "B01001_044E", "B01001_045E", "B01001_046E", "B01001_047E",
                          "B01001_048E",
                          "B01001_049E"), {'for': 'state:*'})

# %%
census_pd_f = pd.DataFrame(census_data_f)

# %%
census_pd_f = census_pd_f.rename(columns={"NAME": "Name", "state": "State"})

# %%
colf = list(census_pd_f)
colf = colf[1:-1]

# %%
census_pd_f['Seniorsf'] = census_pd_f[colf].sum(axis=1)

# %%
census_pd_f = census_pd_f[['Name', 'Seniorsf']]

# %%
census_pd_f
# Out:
#                     Name   Seniorsf
# 0                  Maine   151196.0
# 1         North Carolina   950712.0
# 2                Georgia   822753.0
# 3                 Alaska    43683.0
# 4                Alabama   468693.0
# 5                Vermont    67099.0
# 6                 Nevada   251204.0
# 7          West Virginia   196488.0
# 8               Oklahoma   343864.0
# 9              Wisconsin   536561.0
# 10           Puerto Rico   373339.0
# 11              Virginia   733844.0
# 12          North Dakota    62667.0
# 13        South Carolina   500498.0
# 14                Oregon   398831.0
# 15               Wyoming    50497.0
# 16            California  3145820.0
# 17           Mississippi   268754.0
# 18           Connecticut   345275.0
# 19                 Texas  1993719.0
# 20              Maryland   529562.0
# 21               Florida  2393229.0
# 22         Massachusetts   644751.0
# 23  District of Columbia    50396.0
# 24                  Utah   187229.0
# 25              New York  1830958.0
# 26            New Jersey   817766.0
# 27                  Ohio  1121286.0
# 28              Missouri   578254.0
# 29          Pennsylvania  1311544.0
# 30              Michigan   951250.0
# 31              Nebraska   167153.0
# 32                 Idaho   146975.0
# 33            New Mexico   200155.0
# 34                Hawaii   142768.0
# 35          South Dakota    78374.0
# 36            Washington   631632.0
# 37          Rhode Island   103090.0
# 38               Arizona   679703.0
# 39             Tennessee   615539.0
# 40                Kansas   255071.0
# 41              Colorado   438527.0
# 42               Indiana   588609.0
# 43              Kentucky   408000.0
# 44             Louisiana   405111.0
# 45              Illinois  1120812.0
# 46                  Iowa   298303.0
# 47         New Hampshire   133054.0
# 48              Arkansas   281554.0
# 49              Delaware    99777.0
# 50             Minnesota   485580.0
# 51               Montana   104046.0

# %% [markdown]
# ### Combine Male and Female Data

# %%
census_data = census_pd_male[['Name', 'Population', 'Seniors']].set_index('Name')

# %%
census_data = census_data.join(census_pd_f.set_index('Name'))

# %%
census_data['Percent_Seniors'] = ((census_data['Seniors'] + census_data['Seniorsf'])/census_data['Population'])*100

# %%
census_data = census_data[['Population', 'Percent_Seniors']].reset_index()

# %%
census_data
# Out:
#                     Name  Population  Percent_Seniors
# 0                  Maine   1338404.0        20.626732
# 1         North Carolina  10383620.0        16.261901
# 2                Georgia  10519475.0        13.845064
# 3                 Alaska    737438.0        11.933207
# 4                Alabama   4887871.0        16.973914
# 5                Vermont    626299.0        19.778892
# 6                 Nevada   3034392.0        15.657832
# 7          West Virginia   1805832.0        20.002747
# 8               Oklahoma   3943079.0        15.713634
# 9              Wisconsin   5813568.0        16.968633
# 10           Puerto Rico   3195153.0        20.694345
# 11              Virginia   8517685.0        15.476330
# 12          North Dakota    760077.0        15.318580
# 13        South Carolina   5084127.0        17.697316
# 14                Oregon   4190713.0        17.648811
# 15               Wyoming    577737.0        16.712968
# 16            California  39557045.0        14.326998
# 17           Mississippi   2986530.0        15.885426
# 18           Connecticut   3572665.0        17.162174
# 19                 Texas  28701845.0        12.541351
# 20              Maryland   6042718.0        15.407653
# 21               Florida  21299325.0        20.464423
# 22         Massachusetts   6902149.0        16.480968
# 23  District of Columbia    702455.0        12.189535
# 24                  Utah   3161105.0        11.113108
# 25              New York  19542209.0        16.436550
# 26            New Jersey   8908520.0        16.145095
# 27                  Ohio  11689442.0        17.076632
# 28              Missouri   6126452.0        16.895162
# 29          Pennsylvania  12807060.0        18.211588
# 30              Michigan   9995915.0        17.211561
# 31              Nebraska   1929268.0        15.757168
# 32                 Idaho   1754208.0        15.929753
# 33            New Mexico   2095428.0        17.584952
# 34                Hawaii   1420491.0        18.406804
# 35          South Dakota    882235.0        16.589457
# 36            Washington   7535591.0        15.446526
# 37          Rhode Island   1057315.0        17.274417
# 38               Arizona   7171646.0        17.556681
# 39             Tennessee   6770010.0        16.318986
# 40                Kansas   2911510.0        15.874615
# 41              Colorado   5695564.0        14.183933
# 42               Indiana   6691878.0        15.707788
# 43              Kentucky   4468402.0        16.368089
# 44             Louisiana   4659978.0        15.463807
# 45              Illinois  12741080.0        15.623071
# 46                  Iowa   3156145.0        17.040345
# 47         New Hampshire   1356458.0        18.073247
# 48              Arkansas   3013825.0        16.844906
# 49              Delaware    967171.0        18.689146
# 50             Minnesota   5611179.0        15.836850
# 51               Montana   1062305.0        18.849483

# %%
census_data = census_data[census_data['Name'].isin(['California', 'Florida', 'New York', 
                                                  'Michigan', 'New Jersey', 'Washington'])]

# %%
census_data
# Out:
#           Name  Population  Percent_Seniors
# 16  California  39557045.0        14.326998
# 21     Florida  21299325.0        20.464423
# 25    New York  19542209.0        16.436550
# 26  New Jersey   8908520.0        16.145095
# 30    Michigan   9995915.0        17.211561
# 36  Washington   7535591.0        15.446526

# %%
census_data.to_csv('out.csv', index=False)

# %%
from sqlalchemy import create_engine

# %%
rds_connection_string = "postgres:postgres@localhost:5432/test"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['test']

# %%
census_data.to_sql(name='test', con=engine, if_exists='append', index=False)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
def split(x):
    if ' ' in x:
        y = x.split(' ')[0]
    elif 'T' in x:
        y = x.split('T')[0]
    return y

# %%
def fix(x):
    x = split(x)
    if '/' in x:
        if '2020' in x:
            y = datetime.strptime(x, '%m/%d/%Y').date()
        else:
            y = datetime.strptime(x, '%m/%d/%y').date()
    elif '-' in x:
        if '2020' in x:
            y = datetime.strptime(x, '%Y-%m-%d')
        else:
            y = datetime.strptime(x, '%y-%m-%d').date()
    return y

# %%
pth = '../US_covid_cases.csv'
us = pd.read_csv(pth)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ece1faecf29e> in <module>
#       1 pth = '../US_covid_cases.csv'
# ----> 2 us = pd.read_csv(pth)
#
# NameError: name 'pd' is not defined

# %%
'WA' in 'Seattle, WA'
# Out:
# True

# %%
wash = us[(us['Province_State'] == 'Washington') | (us['Province_State'].str.contains('WA'))]

# %%
wash
# Out:
#        Unnamed: 0  Confirmed Country_Region  Deaths          Last_Update  \
# 0              31        1.0             US     NaN      1/22/2020 17:00
# 1              31        1.0             US     NaN        1/23/20 17:00
# 2              33        1.0             US     NaN        1/24/20 17:00
# 4              33        1.0             US     NaN        1/25/20 17:00
# 6              33        1.0             US     NaN        1/26/20 16:00
# ...           ...        ...            ...     ...                  ...
# 23563        2936        0.0             US     0.0  2020-03-28 23:05:37
# 23570        2943        4.0             US     0.0  2020-03-28 23:05:37
# 23684        3057      102.0             US     4.0  2020-03-28 23:05:37
# 23700        3073        6.0             US     0.0  2020-03-28 23:05:37
# 23770        3143       82.0             US     2.0  2020-03-28 23:05:37
#
#              Lat       Long_ Province_State  Recovered
# ...

# %%
wash = wash[['Province_State', 'Confirmed', 'Deaths', 'Recovered', 'Last_Update']]

# %%
wash['Date'] = wash['Last_Update'].apply(fix)

# %%
wash
# Out:
#       Province_State  Confirmed  Deaths  Recovered          Last_Update  \
# 0         Washington        1.0     NaN        NaN      1/22/2020 17:00
# 1         Washington        1.0     NaN        NaN        1/23/20 17:00
# 2         Washington        1.0     NaN        NaN        1/24/20 17:00
# 4         Washington        1.0     NaN        NaN        1/25/20 17:00
# 6         Washington        1.0     NaN        NaN        1/26/20 16:00
# ...              ...        ...     ...        ...                  ...
# 23563     Washington        0.0     0.0        0.0  2020-03-28 23:05:37
# 23570     Washington        4.0     0.0        0.0  2020-03-28 23:05:37
# 23684     Washington      102.0     4.0        0.0  2020-03-28 23:05:37
# 23700     Washington        6.0     0.0        0.0  2020-03-28 23:05:37
# 23770     Washington       82.0     2.0        0.0  2020-03-28 23:05:37
#
#              Date
# 0      2020-01-22
# 1      2020-01-23
# 2      2020-01-24
# 4      2020-01-25
# ...

# %%
wash = wash.drop_duplicates(['Province_State', 'Last_Update', 'Date'])

# %%
wash.count()
# Out:
# Province_State    59
# Confirmed         59
# Deaths            49
# Recovered         49
# Last_Update       59
# Date              59
# dtype: int64

# %%
wash = wash.fillna(0)
wash = wash.groupby('Date').sum()

# %%
wash
# Out:
#             Confirmed  Deaths  Recovered
# Date
# 2020-01-22        1.0     0.0        0.0
# 2020-01-23        1.0     0.0        0.0
# 2020-01-24        1.0     0.0        0.0
# 2020-01-25        1.0     0.0        0.0
# 2020-01-26        1.0     0.0        0.0
# 2020-01-27        1.0     0.0        0.0
# 2020-01-28        1.0     0.0        0.0
# 2020-01-29        1.0     0.0        0.0
# 2020-01-30        1.0     0.0        0.0
# 2020-01-31        1.0     0.0        0.0
# 2020-02-01        2.0     0.0        0.0
# 2020-02-09        1.0     0.0        1.0
# 2020-02-29        7.0     1.0        1.0
# 2020-03-01       11.0     1.0        1.0
# 2020-03-02       18.0     6.0        1.0
# 2020-03-03       27.0     7.0        1.0
# 2020-03-04       39.0    10.0        1.0
# 2020-03-05       70.0    11.0        1.0
# 2020-03-06       82.0    13.0        1.0
# 2020-03-07      101.0    16.0        1.0
# 2020-03-08      120.0    18.0        1.0
# 2020-03-09        1.0     1.0        0.0
# ...
